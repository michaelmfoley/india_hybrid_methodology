# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.lines import Line2D
import os
import warnings
warnings.filterwarnings("ignore", category=UserWarning, message="Geometry is in a geographic CRS.*")
warnings.simplefilter(action="ignore", category=pd.errors.SettingWithCopyWarning)

# %% [markdown]
# # Load in hybrid boundary stats

# %%
shp_path = "../shapefiles/2016_2023_hybrid_boundary_071925.shp" 
hybrid = gpd.read_file(shp_path)

# %%
ag_stats_path = "../../data/ag_stats_final_071925.csv"
unmerged_stats = pd.read_csv(ag_stats_path)
unmerged_stats.columns
# Out:
# Index(['Data Source Organization', 'Data Source Document', 'Publication Name',
#        'Survey Type', 'Country', 'Zone', 'FNID', 'Admin 1', 'Admin 2',
#        'Admin 3', 'Year', 'Start Period', 'Season', 'End Period', 'Crop',
#        'Dominant Production System', 'Area Planted: ha', 'Area Harvested: ha',
#        'Yield: MT/ha', 'Quantity Produced: MT', 'Contributions by',
#        'Source crop', 'DNL_Source_year'],
#       dtype='object')

# %%
unmerged_stats
# Out:
#        Data Source Organization  \
# 0               MoA & FW, India
# 1               MoA & FW, India
# 2               MoA & FW, India
# 3               MoA & FW, India
# 4               MoA & FW, India
# ...                         ...
# 365984          MoA & FW, India
# 365985          MoA & FW, India
# 365986          MoA & FW, India
# 365987          MoA & FW, India
# 365988          MoA & FW, India
#
#                                  Data Source Document  \
# 0       Official agricultural statistics, India, crop
# 1       Official agricultural statistics, India, crop
# 2       Official agricultural statistics, India, crop
# 3       Official agricultural statistics, India, crop
# 4       Official agricultural statistics, India, crop
# ...                                               ...
# 365984  Official agricultural statistics, India, crop
# 365985  Official agricultural statistics, India, crop
# 365986  Official agricultural statistics, India, crop
# 365987  Official agricultural statistics, India, crop
# 365988  Official agricultural statistics, India, crop
#
#                                          Publication Name Survey Type Country  \
# 0       https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 1       https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 2       https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 3       https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 4       https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# ...                                                   ...         ...     ...
# 365984  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 365985  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 365986  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 365987  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 365988  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
#
#         Zone  FNID                 Admin 1                      Admin 2  \
# 0        NaN   NaN          Andhra Pradesh   Alluri Sitharama Raju (AP)
# 1        NaN   NaN          Andhra Pradesh   Alluri Sitharama Raju (AP)
# 2        NaN   NaN          Andhra Pradesh              YSR Kadapa (AP)
# 3        NaN   NaN          Andhra Pradesh              YSR Kadapa (AP)
# 4        NaN   NaN          Andhra Pradesh              YSR Kadapa (AP)
# ...      ...   ...                     ...                          ...
# 365984   NaN   NaN  Dadra and Nagar Haveli  Dadra And Nagar Haveli (DN)
# 365985   NaN   NaN  Dadra and Nagar Haveli  Dadra And Nagar Haveli (DN)
# 365986   NaN   NaN  Dadra and Nagar Haveli  Dadra And Nagar Haveli (DN)
# 365987   NaN   NaN  Dadra and Nagar Haveli  Dadra And Nagar Haveli (DN)
# 365988   NaN   NaN                   Delhi             Delhi_Total (DL)
#
#         Admin 3  ...  End Period Crop Dominant Production System  \
# 0           NaN  ...   9/30/2022  NaN                   All (PS)
# 1           NaN  ...   9/30/2022  NaN                   All (PS)
# 2           NaN  ...   9/30/1997  NaN                   All (PS)
# 3           NaN  ...   1/31/1998  NaN                   All (PS)
# 4           NaN  ...   9/30/1998  NaN                   All (PS)
# ...         ...  ...         ...  ...                        ...
# 365984      NaN  ...   9/30/2019  NaN                   All (PS)
# 365985      NaN  ...   1/31/2020  NaN                   All (PS)
# 365986      NaN  ...   1/31/2020  NaN                   All (PS)
# 365987      NaN  ...   9/30/2019  NaN                   All (PS)
# 365988      NaN  ...   1/31/2020  NaN                   All (PS)
#
#        Area Planted: ha  Area Harvested: ha Yield: MT/ha  \
# 0                   NaN             14946.0         1.03
# 1                   NaN              2181.0         0.50
# 2                   NaN               100.0         1.00
# 3                   NaN               800.0         1.63
# 4                   NaN               100.0         1.00
# ...                 ...                 ...          ...
# 365984              NaN                10.0         0.30
# 365985              NaN                20.0         0.40
# 365986              NaN                 5.0         0.50
# 365987              NaN                 6.0         0.25
# 365988              NaN              3250.0         2.50
#
#         Quantity Produced: MT  Contributions by        Source crop  \
# 0                     15394.0           Harvard               Ragi
# 1                      1093.0           Harvard      Small millets
# 2                       100.0           Harvard               Ragi
# 3                      1300.0           Harvard               Ragi
# 4                       100.0           Harvard               Ragi
# ...                       ...               ...                ...
# 365984                    3.0           Harvard         Niger seed
# 365985                    8.0           Harvard         Niger seed
# 365986                    2.5           Harvard  Rapeseed &Mustard
# 365987                    1.5           Harvard            Sesamum
# 365988                 8125.0           Harvard  Rapeseed &Mustard
#
#         DNL_Source_year
# 0               2022-23
# 1               2022-23
# 2               1997-98
# 3               1997-98
# 4               1998-99
# ...                 ...
# 365984          2019-20
# 365985          2019-20
# 365986          2019-20
# 365987          2019-20
# 365988          2019-20
#
# [365989 rows x 23 columns]

# %%
hybrid
# Out:
#            id        boundary              name  wikidata  \
# 0      726993  administrative  Lahaul and Spiti   Q837595
# 1      728093  administrative           Kinnaur  Q1862950
# 2      728111  administrative             Kullu  Q2980880
# 3      728141  administrative            Chamba  Q1060614
# 4      728149  administrative            Kangra   Q727232
# ..        ...             ...               ...       ...
# 671   4055745  administrative        Tamenglong  Q2301717
# 672   4055741  administrative     Churachandpur  Q2577281
# 673   4055941  administrative           Chandel  Q2301769
# 674   3885955  administrative           Bhiwani  Q1852857
# 675  19029619  administrative               Nuh  Q2216696
#
#                         wikipedia             STATE             name_state  \
# 0    en:Lahaul and Spiti district  HIMACHAL PRADESH  Lahaul and Spiti (HP)
# 1             en:Kinnaur district  HIMACHAL PRADESH           Kinnaur (HP)
# 2               en:Kullu district  HIMACHAL PRADESH             Kullu (HP)
# 3                    hi:चंबा जिला  HIMACHAL PRADESH            Chamba (HP)
# 4              en:Kangra district  HIMACHAL PRADESH            Kangra (HP)
# ..                            ...               ...                    ...
# 671        en:Tamenglong district           MANIPUR        Tamenglong (MN)
# 672     en:Churachandpur district           MANIPUR     Churachandpur (MN)
# 673           en:Chandel district           MANIPUR           Chandel (MN)
# 674           en:Bhiwani district           HARYANA           Bhiwani (HR)
# 675             en:Mewat_district           HARYANA             Mewat (HR)
#
#                             merged_dis  combined  group_numb  multidistr  \
# 0                                 None     False         0.0         0.0
# 1                                 None     False         0.0         0.0
# 2                                 None     False         0.0         0.0
# 3                                 None     False         0.0         0.0
# 4                                 None     False         0.0         0.0
# ..                                 ...       ...         ...         ...
# 671        Noney (MN), Tamenglong (MN)      True        75.0         0.0
# 672  Churachandpur (MN), Pherzawl (MN)      True        76.0         0.0
# 673      Chandel (MN), Tengnoupal (MN)      True        77.0         0.0
# 674   Bhiwani (HR), Charkhi Dadri (HR)      True        78.0         0.0
# 675                           Nuh (HR)      True        79.0        -1.0
#
#      change_yea                                           geometry
# 0           0.0  POLYGON ((76.3713 32.80479, 76.3718 32.81253, ...
# 1           0.0  POLYGON ((77.74825 31.71353, 77.75089 31.71643...
# 2           0.0  POLYGON ((76.93577 32.09072, 76.9358 32.09486,...
# 3           0.0  POLYGON ((75.79671 32.88423, 75.79928 32.88556...
# 4           0.0  POLYGON ((75.59401 32.07734, 75.5954 32.08443,...
# ..          ...                                                ...
# 671      2016.0  POLYGON ((93.17167 24.52091, 93.17245 24.5226,...
# 672      2016.0  POLYGON ((93.3966 24.57814, 93.44967 24.54201,...
# 673      2016.0  POLYGON ((93.74015 24.01521, 93.74113 24.01584...
# 674      2016.0  POLYGON ((76.33312 28.81269, 76.33367 28.81163...
# 675      2016.0  POLYGON ((76.8541 28.221, 76.85732 28.22507, 7...
#
# [676 rows x 13 columns]

# %%
print(117614.1*1000/unmerged_stats[(unmerged_stats['Year'] == 2016) & (unmerged_stats['Source crop'] == 'Rice')]['Quantity Produced: MT'].sum())
print(42963.71000000001*1000/unmerged_stats[(unmerged_stats['Year'] == 2016) & (unmerged_stats['Source crop'] == 'Rice')]['Area Harvested: ha'].sum())
# Out:
# 0.9888845647210223
# 0.9735988619668309

# %% [markdown]
# # Merge Them Based on Names

# %%
hybrid
# Out:
#            id        boundary              name  wikidata  \
# 0      726993  administrative  Lahaul and Spiti   Q837595
# 1      728093  administrative           Kinnaur  Q1862950
# 2      728111  administrative             Kullu  Q2980880
# 3      728141  administrative            Chamba  Q1060614
# 4      728149  administrative            Kangra   Q727232
# ..        ...             ...               ...       ...
# 671   4055745  administrative        Tamenglong  Q2301717
# 672   4055741  administrative     Churachandpur  Q2577281
# 673   4055941  administrative           Chandel  Q2301769
# 674   3885955  administrative           Bhiwani  Q1852857
# 675  19029619  administrative               Nuh  Q2216696
#
#                         wikipedia             STATE             name_state  \
# 0    en:Lahaul and Spiti district  HIMACHAL PRADESH  Lahaul and Spiti (HP)
# 1             en:Kinnaur district  HIMACHAL PRADESH           Kinnaur (HP)
# 2               en:Kullu district  HIMACHAL PRADESH             Kullu (HP)
# 3                    hi:चंबा जिला  HIMACHAL PRADESH            Chamba (HP)
# 4              en:Kangra district  HIMACHAL PRADESH            Kangra (HP)
# ..                            ...               ...                    ...
# 671        en:Tamenglong district           MANIPUR        Tamenglong (MN)
# 672     en:Churachandpur district           MANIPUR     Churachandpur (MN)
# 673           en:Chandel district           MANIPUR           Chandel (MN)
# 674           en:Bhiwani district           HARYANA           Bhiwani (HR)
# 675             en:Mewat_district           HARYANA             Mewat (HR)
#
#                             merged_dis  combined  group_numb  multidistr  \
# 0                                 None     False         0.0         0.0
# 1                                 None     False         0.0         0.0
# 2                                 None     False         0.0         0.0
# 3                                 None     False         0.0         0.0
# 4                                 None     False         0.0         0.0
# ..                                 ...       ...         ...         ...
# 671        Noney (MN), Tamenglong (MN)      True        75.0         0.0
# 672  Churachandpur (MN), Pherzawl (MN)      True        76.0         0.0
# 673      Chandel (MN), Tengnoupal (MN)      True        77.0         0.0
# 674   Bhiwani (HR), Charkhi Dadri (HR)      True        78.0         0.0
# 675                           Nuh (HR)      True        79.0        -1.0
#
#      change_yea                                           geometry
# 0           0.0  POLYGON ((76.3713 32.80479, 76.3718 32.81253, ...
# 1           0.0  POLYGON ((77.74825 31.71353, 77.75089 31.71643...
# 2           0.0  POLYGON ((76.93577 32.09072, 76.9358 32.09486,...
# 3           0.0  POLYGON ((75.79671 32.88423, 75.79928 32.88556...
# 4           0.0  POLYGON ((75.59401 32.07734, 75.5954 32.08443,...
# ..          ...                                                ...
# 671      2016.0  POLYGON ((93.17167 24.52091, 93.17245 24.5226,...
# 672      2016.0  POLYGON ((93.3966 24.57814, 93.44967 24.54201,...
# 673      2016.0  POLYGON ((93.74015 24.01521, 93.74113 24.01584...
# 674      2016.0  POLYGON ((76.33312 28.81269, 76.33367 28.81163...
# 675      2016.0  POLYGON ((76.8541 28.221, 76.85732 28.22507, 7...
#
# [676 rows x 13 columns]

# %%
# We need to take care of cases where the name was officially changed but the data still has the old name. For India, this is the case for:
# - Ayodhya (UP) which was previously known as Faizabad (UP).
# - Nuh (HR) which was previously known as Mewat (HR).
# - Mangan (SK) which was previously known as North Sikkim (SK).
# - Namchi (SK) which was previously known as South Sikkim (SK).
# The shapefile has the correct names for 2016, but the data has the correct names for 2022. We will need to individually change these names in the data to match the shapefile.
extra_mapping = {
    'Ayodhya (UP)': 'Faizabad (UP)',
    'Nuh (HR)': 'Mewat (HR)',
    
}

# %%
unmerged_stats
# Out:
#        Data Source Organization  \
# 0               MoA & FW, India
# 1               MoA & FW, India
# 2               MoA & FW, India
# 3               MoA & FW, India
# 4               MoA & FW, India
# ...                         ...
# 365984          MoA & FW, India
# 365985          MoA & FW, India
# 365986          MoA & FW, India
# 365987          MoA & FW, India
# 365988          MoA & FW, India
#
#                                  Data Source Document  \
# 0       Official agricultural statistics, India, crop
# 1       Official agricultural statistics, India, crop
# 2       Official agricultural statistics, India, crop
# 3       Official agricultural statistics, India, crop
# 4       Official agricultural statistics, India, crop
# ...                                               ...
# 365984  Official agricultural statistics, India, crop
# 365985  Official agricultural statistics, India, crop
# 365986  Official agricultural statistics, India, crop
# 365987  Official agricultural statistics, India, crop
# 365988  Official agricultural statistics, India, crop
#
#                                          Publication Name Survey Type Country  \
# 0       https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 1       https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 2       https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 3       https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 4       https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# ...                                                   ...         ...     ...
# 365984  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 365985  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 365986  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 365987  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 365988  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
#
#         Zone  FNID                 Admin 1                      Admin 2  \
# 0        NaN   NaN          Andhra Pradesh   Alluri Sitharama Raju (AP)
# 1        NaN   NaN          Andhra Pradesh   Alluri Sitharama Raju (AP)
# 2        NaN   NaN          Andhra Pradesh              YSR Kadapa (AP)
# 3        NaN   NaN          Andhra Pradesh              YSR Kadapa (AP)
# 4        NaN   NaN          Andhra Pradesh              YSR Kadapa (AP)
# ...      ...   ...                     ...                          ...
# 365984   NaN   NaN  Dadra and Nagar Haveli  Dadra And Nagar Haveli (DN)
# 365985   NaN   NaN  Dadra and Nagar Haveli  Dadra And Nagar Haveli (DN)
# 365986   NaN   NaN  Dadra and Nagar Haveli  Dadra And Nagar Haveli (DN)
# 365987   NaN   NaN  Dadra and Nagar Haveli  Dadra And Nagar Haveli (DN)
# 365988   NaN   NaN                   Delhi             Delhi_Total (DL)
#
#         Admin 3  ...  End Period Crop Dominant Production System  \
# 0           NaN  ...   9/30/2022  NaN                   All (PS)
# 1           NaN  ...   9/30/2022  NaN                   All (PS)
# 2           NaN  ...   9/30/1997  NaN                   All (PS)
# 3           NaN  ...   1/31/1998  NaN                   All (PS)
# 4           NaN  ...   9/30/1998  NaN                   All (PS)
# ...         ...  ...         ...  ...                        ...
# 365984      NaN  ...   9/30/2019  NaN                   All (PS)
# 365985      NaN  ...   1/31/2020  NaN                   All (PS)
# 365986      NaN  ...   1/31/2020  NaN                   All (PS)
# 365987      NaN  ...   9/30/2019  NaN                   All (PS)
# 365988      NaN  ...   1/31/2020  NaN                   All (PS)
#
#        Area Planted: ha  Area Harvested: ha Yield: MT/ha  \
# 0                   NaN             14946.0         1.03
# 1                   NaN              2181.0         0.50
# 2                   NaN               100.0         1.00
# 3                   NaN               800.0         1.63
# 4                   NaN               100.0         1.00
# ...                 ...                 ...          ...
# 365984              NaN                10.0         0.30
# 365985              NaN                20.0         0.40
# 365986              NaN                 5.0         0.50
# 365987              NaN                 6.0         0.25
# 365988              NaN              3250.0         2.50
#
#         Quantity Produced: MT  Contributions by        Source crop  \
# 0                     15394.0           Harvard               Ragi
# 1                      1093.0           Harvard      Small millets
# 2                       100.0           Harvard               Ragi
# 3                      1300.0           Harvard               Ragi
# 4                       100.0           Harvard               Ragi
# ...                       ...               ...                ...
# 365984                    3.0           Harvard         Niger seed
# 365985                    8.0           Harvard         Niger seed
# 365986                    2.5           Harvard  Rapeseed &Mustard
# 365987                    1.5           Harvard            Sesamum
# 365988                 8125.0           Harvard  Rapeseed &Mustard
#
#         DNL_Source_year
# 0               2022-23
# 1               2022-23
# 2               1997-98
# 3               1997-98
# 4               1998-99
# ...                 ...
# 365984          2019-20
# 365985          2019-20
# 365986          2019-20
# 365987          2019-20
# 365988          2019-20
#
# [365989 rows x 23 columns]

# %%
hybrid
# Out:
#            id        boundary              name  wikidata  \
# 0      726993  administrative  Lahaul and Spiti   Q837595
# 1      728093  administrative           Kinnaur  Q1862950
# 2      728111  administrative             Kullu  Q2980880
# 3      728141  administrative            Chamba  Q1060614
# 4      728149  administrative            Kangra   Q727232
# ..        ...             ...               ...       ...
# 671   4055745  administrative        Tamenglong  Q2301717
# 672   4055741  administrative     Churachandpur  Q2577281
# 673   4055941  administrative           Chandel  Q2301769
# 674   3885955  administrative           Bhiwani  Q1852857
# 675  19029619  administrative               Nuh  Q2216696
#
#                         wikipedia             STATE             name_state  \
# 0    en:Lahaul and Spiti district  HIMACHAL PRADESH  Lahaul and Spiti (HP)
# 1             en:Kinnaur district  HIMACHAL PRADESH           Kinnaur (HP)
# 2               en:Kullu district  HIMACHAL PRADESH             Kullu (HP)
# 3                    hi:चंबा जिला  HIMACHAL PRADESH            Chamba (HP)
# 4              en:Kangra district  HIMACHAL PRADESH            Kangra (HP)
# ..                            ...               ...                    ...
# 671        en:Tamenglong district           MANIPUR        Tamenglong (MN)
# 672     en:Churachandpur district           MANIPUR     Churachandpur (MN)
# 673           en:Chandel district           MANIPUR           Chandel (MN)
# 674           en:Bhiwani district           HARYANA           Bhiwani (HR)
# 675             en:Mewat_district           HARYANA             Mewat (HR)
#
#                             merged_dis  combined  group_numb  multidistr  \
# 0                                 None     False         0.0         0.0
# 1                                 None     False         0.0         0.0
# 2                                 None     False         0.0         0.0
# 3                                 None     False         0.0         0.0
# 4                                 None     False         0.0         0.0
# ..                                 ...       ...         ...         ...
# 671        Noney (MN), Tamenglong (MN)      True        75.0         0.0
# 672  Churachandpur (MN), Pherzawl (MN)      True        76.0         0.0
# 673      Chandel (MN), Tengnoupal (MN)      True        77.0         0.0
# 674   Bhiwani (HR), Charkhi Dadri (HR)      True        78.0         0.0
# 675                           Nuh (HR)      True        79.0        -1.0
#
#      change_yea                                           geometry
# 0           0.0  POLYGON ((76.3713 32.80479, 76.3718 32.81253, ...
# 1           0.0  POLYGON ((77.74825 31.71353, 77.75089 31.71643...
# 2           0.0  POLYGON ((76.93577 32.09072, 76.9358 32.09486,...
# 3           0.0  POLYGON ((75.79671 32.88423, 75.79928 32.88556...
# 4           0.0  POLYGON ((75.59401 32.07734, 75.5954 32.08443,...
# ..          ...                                                ...
# 671      2016.0  POLYGON ((93.17167 24.52091, 93.17245 24.5226,...
# 672      2016.0  POLYGON ((93.3966 24.57814, 93.44967 24.54201,...
# 673      2016.0  POLYGON ((93.74015 24.01521, 93.74113 24.01584...
# 674      2016.0  POLYGON ((76.33312 28.81269, 76.33367 28.81163...
# 675      2016.0  POLYGON ((76.8541 28.221, 76.85732 28.22507, 7...
#
# [676 rows x 13 columns]

# %%
unmerged = unmerged_stats[['Admin 2', 'Year', 'Area Harvested: ha', 'Yield: MT/ha', 'Quantity Produced: MT', 'Source crop']]
unmerged.columns = ["name_state", "year", "area_harvested", "yield", "production", "ag_hy_crop"]

# %%
len(unmerged['name_state'].unique())
# Out:
# 747

# %%
merged = unmerged.merge(hybrid, how='left')
merged = gpd.GeoDataFrame(merged, geometry='geometry')

# %%
merged
# Out:
#                          name_state  year  area_harvested  yield  production  \
# 0        Alluri Sitharama Raju (AP)  2022         14946.0   1.03     15394.0
# 1        Alluri Sitharama Raju (AP)  2022          2181.0   0.50      1093.0
# 2                   YSR Kadapa (AP)  1997           100.0   1.00       100.0
# 3                   YSR Kadapa (AP)  1997           800.0   1.63      1300.0
# 4                   YSR Kadapa (AP)  1998           100.0   1.00       100.0
# ...                             ...   ...             ...    ...         ...
# 365984  Dadra And Nagar Haveli (DN)  2019            10.0   0.30         3.0
# 365985  Dadra And Nagar Haveli (DN)  2019            20.0   0.40         8.0
# 365986  Dadra And Nagar Haveli (DN)  2019             5.0   0.50         2.5
# 365987  Dadra And Nagar Haveli (DN)  2019             6.0   0.25         1.5
# 365988             Delhi_Total (DL)  2019          3250.0   2.50      8125.0
#
#                ag_hy_crop  id boundary name wikidata wikipedia STATE  \
# 0                    Ragi NaN      NaN  NaN      NaN       NaN   NaN
# 1           Small millets NaN      NaN  NaN      NaN       NaN   NaN
# 2                    Ragi NaN      NaN  NaN      NaN       NaN   NaN
# 3                    Ragi NaN      NaN  NaN      NaN       NaN   NaN
# 4                    Ragi NaN      NaN  NaN      NaN       NaN   NaN
# ...                   ...  ..      ...  ...      ...       ...   ...
# 365984         Niger seed NaN      NaN  NaN      NaN       NaN   NaN
# 365985         Niger seed NaN      NaN  NaN      NaN       NaN   NaN
# 365986  Rapeseed &Mustard NaN      NaN  NaN      NaN       NaN   NaN
# 365987            Sesamum NaN      NaN  NaN      NaN       NaN   NaN
# 365988  Rapeseed &Mustard NaN      NaN  NaN      NaN       NaN   NaN
#
#        merged_dis combined  group_numb  multidistr  change_yea geometry
# 0             NaN      NaN         NaN         NaN         NaN     None
# 1             NaN      NaN         NaN         NaN         NaN     None
# 2             NaN      NaN         NaN         NaN         NaN     None
# 3             NaN      NaN         NaN         NaN         NaN     None
# 4             NaN      NaN         NaN         NaN         NaN     None
# ...           ...      ...         ...         ...         ...      ...
# 365984        NaN      NaN         NaN         NaN         NaN     None
# 365985        NaN      NaN         NaN         NaN         NaN     None
# 365986        NaN      NaN         NaN         NaN         NaN     None
# 365987        NaN      NaN         NaN         NaN         NaN     None
# 365988        NaN      NaN         NaN         NaN         NaN     None
#
# [365989 rows x 18 columns]

# %%
from matplotlib.colors import LinearSegmentedColormap

test = merged[(merged['ag_hy_crop']=="Rice") & (merged['year']==2016)]
fig, ax = plt.subplots(figsize=(30, 20))
hybrid.boundary.plot(ax=ax, linewidth=1, color='black')
test.plot(ax=ax, column="yield", cmap='viridis', classification_kwds=dict(bins=[.927,1.438,1.852,2.404,2.762]))
# Out:
# <Axes: >

# %% [markdown]
# # Great - now we must address the districts that have experienced splits or merges, so we should write another file that produces the 'hybrid' statistics.

# %%
import pandas as pd
import geopandas as gpd
import numpy as np

def parse_merging_rules(hybrid_df):
    """
    Create a dictionary mapping each hybrid district to its potential constituent districts
    Handles the specific format: comma-separated strings for merged districts, None for unchanged
    """
    merging_rules = {}
    
    for _, row in hybrid_df.iterrows():
        hybrid_name = row['name_state']
        merged_dis_value = row['merged_dis']
        
        # Handle None values (districts that didn't change)
        if pd.isna(merged_dis_value) or merged_dis_value is None:
            # District maps to itself - no merging occurred
            potential_districts = [hybrid_name]
        else:
            # Parse comma-separated string of constituent districts
            try:
                # Split by comma and clean whitespace
                potential_districts = [district.strip() for district in merged_dis_value.split(',')]
                
                # Remove any empty strings
                potential_districts = [d for d in potential_districts if d]
                
                # If somehow empty after cleaning, map to itself
                if not potential_districts:
                    potential_districts = [hybrid_name]
                    
            except Exception as e:
                print(f"Warning: Could not parse merged_dis for {hybrid_name}: {merged_dis_value}")
                print(f"Error: {e}")
                # Fallback: map to itself
                potential_districts = [hybrid_name]
        
        merging_rules[hybrid_name] = potential_districts
        
    return merging_rules

def analyze_merging_rules(merging_rules):
    """
    Analyze the merging rules to understand the data structure
    """
    print("=== Merging Rules Analysis ===")
    
    # Count districts by number of constituents
    constituent_counts = {}
    for hybrid_name, constituents in merging_rules.items():
        count = len(constituents)
        if count not in constituent_counts:
            constituent_counts[count] = 0
        constituent_counts[count] += 1
    
    print("Districts by number of constituents:")
    for count in sorted(constituent_counts.keys()):
        print(f"  {count} constituent(s): {constituent_counts[count]} districts")
    
    # Show examples of merged districts
    merged_districts = {name: constituents for name, constituents in merging_rules.items() 
                       if len(constituents) > 1}
    
    print(f"\nTotal merged districts: {len(merged_districts)}")
    print("\nSample merged districts:")
    for i, (hybrid_name, constituents) in enumerate(list(merged_districts.items())[:10]):
        print(f"  {hybrid_name}: {constituents}")
    
    return constituent_counts, merged_districts

def aggregate_by_year_presence(crop_df, merging_rules, district_col='Admin 2', year_col='Year'):
    """
    Aggregate crop data year by year, only combining districts that actually exist
    Preserves all metadata columns and only aggregates numeric crop data
    Includes ALL data - both merged and unmerged districts
    """
    all_years_data = []
    
    # Define which columns to aggregate (sum) vs preserve
    aggregate_cols = ['Area Planted: ha', 'Area Harvested: ha', 'Quantity Produced: MT']
    
    # Metadata columns to preserve (take from first constituent district)
    metadata_cols = ['Data Source Organization', 'Data Source Document', 'Publication Name', 
                    'Survey Type', 'Country', 'Zone', 'FNID', 'Admin 1', 'Admin 3',
                    'Start Period', 'Season', 'End Period', 'Crop', 'Dominant Production System',
                    'Contributions by', 'Source crop', 'DNL_Source_year']
    
    # Identify which districts actually need merging (have multiple constituents)
    districts_to_merge = {}
    for hybrid_name, constituents in merging_rules.items():
        if constituents and len(constituents) > 1:
            # Only include if constituents are different from the hybrid name
            # This handles cases where the hybrid district is listed among its own constituents
            unique_constituents = [c for c in constituents if c != hybrid_name]
            if len(unique_constituents) > 0:
                districts_to_merge[hybrid_name] = constituents
    
    print(f"Found {len(districts_to_merge)} districts that require actual merging")
    for hybrid_name, constituents in list(districts_to_merge.items())[:5]:
        print(f"  {hybrid_name}: {constituents}")
    
    # Get all districts in crop data for debugging
    all_crop_districts = set(crop_df[district_col].unique())
    print(f"\nTotal districts in crop data: {len(all_crop_districts)}")
    print(f"Sample crop districts: {list(all_crop_districts)[:10]}")
    
    # Check overlap between merging rules and crop data
    all_constituents_in_rules = set()
    for constituents in districts_to_merge.values():
        all_constituents_in_rules.update(constituents)
    
    overlap = all_constituents_in_rules.intersection(all_crop_districts)
    print(f"Districts in both merging rules and crop data: {len(overlap)}")
    if len(overlap) > 0:
        print(f"Sample overlapping districts: {list(overlap)[:10]}")
    
    for year in sorted(crop_df[year_col].unique()):
        print(f"Processing year {year}...")
        
        # Get all records for this year
        year_data = crop_df[crop_df[year_col] == year].copy()
        all_districts_in_data = set(year_data[district_col].unique())
        
        # Track which districts we've already processed (to avoid double-counting)
        processed_districts = set()
        merging_happened_this_year = False
        
        # First, process districts that actually need merging (multiple constituents)
        for hybrid_name, potential_constituents in districts_to_merge.items():
            # Check which potential constituents actually exist this year
            constituents_present = [d for d in potential_constituents if d in all_districts_in_data]
            
            print(f"  Hybrid {hybrid_name}: {len(constituents_present)} of {len(potential_constituents)} constituents present")
            if len(constituents_present) > 0:
                print(f"    Present: {constituents_present}")
            
            if len(constituents_present) > 1:  # Only merge if we have multiple constituents
                print(f"    -> MERGING {len(constituents_present)} districts")
                merging_happened_this_year = True
                
                # Get data for all present constituent districts
                constituent_data = year_data[year_data[district_col].isin(constituents_present)]
                
                if len(constituent_data) > 0:
                    # Create one aggregated record per crop (don't group by other metadata that might have NaN)
                    # Group only by Crop to handle cases where metadata might be inconsistent
                    for crop, crop_group in constituent_data.groupby('Source crop'):
                        print(f"      Processing crop group: {crop} with {len(crop_group)} records")
                        
                        # Create aggregated row
                        aggregated_row = {}
                        
                        # Preserve metadata from first record in group
                        first_record = crop_group.iloc[0]
                        for col in metadata_cols:
                            if col in crop_group.columns:
                                aggregated_row[col] = first_record[col]
                        
                        # Set year and hybrid district
                        aggregated_row[year_col] = year
                        aggregated_row[district_col] = hybrid_name  # Replace Admin 2 with hybrid name
                        aggregated_row['Source crop'] = crop
                        
                        # Aggregate numeric columns
                        for col in aggregate_cols:
                            if col in crop_group.columns:
                                aggregated_row[col] = crop_group[col].sum()
                        
                        # Calculate yield as Quantity Produced / Area Harvested
                        if ('Quantity Produced: MT' in aggregated_row and 
                            'Area Harvested: ha' in aggregated_row and 
                            aggregated_row['Area Harvested: ha'] > 0):
                            aggregated_row['Yield: MT/ha'] = (aggregated_row['Quantity Produced: MT'] / 
                                                             aggregated_row['Area Harvested: ha'])
                        else:
                            aggregated_row['Yield: MT/ha'] = np.nan
                        
                        # Add merging status info - THIS IS THE KEY FIX
                        aggregated_row['is_merged'] = True
                        aggregated_row['constituent_districts'] = [d for d in constituents_present if d in crop_group[district_col].values]
                        aggregated_row['num_constituents'] = len(aggregated_row['constituent_districts'])
                        
                        print(f"    Created merged record: {hybrid_name}, crop: {crop}, is_merged = {aggregated_row['is_merged']}")
                        
                        all_years_data.append(aggregated_row)
                    
                    # Mark these districts as processed
                    processed_districts.update(constituents_present)
            
            elif len(constituents_present) == 1:
                # Single constituent present - treat as unmerged but still process
                single_district = constituents_present[0]
                if single_district not in processed_districts:
                    district_data = year_data[year_data[district_col] == single_district]
                    for _, row in district_data.iterrows():
                        row_dict = row.copy().to_dict()
                        # Update district name to hybrid name if different
                        if single_district != hybrid_name:
                            row_dict[district_col] = hybrid_name
                        row_dict['is_merged'] = False
                        row_dict['constituent_districts'] = [single_district]
                        row_dict['num_constituents'] = 1
                        all_years_data.append(row_dict)
                    processed_districts.add(single_district)
        
        # ADDITION: Process name changes separately (single constituent with different name)
        for hybrid_name, constituents in merging_rules.items():
            if (constituents and len(constituents) == 1 and 
                constituents[0] != hybrid_name and 
                constituents[0] in all_districts_in_data and
                constituents[0] not in processed_districts):
                
                single_district = constituents[0]
                print(f"  Processing NAME CHANGE: {single_district} -> {hybrid_name}")
                
                district_data = year_data[year_data[district_col] == single_district]
                print(f"    Found {len(district_data)} records for name change")
                
                for _, row in district_data.iterrows():
                    row_dict = row.copy().to_dict()
                    # Update district name to hybrid name
                    row_dict[district_col] = hybrid_name
                    row_dict['is_merged'] = True  # Mark name changes as merged
                    row_dict['constituent_districts'] = [single_district]
                    row_dict['num_constituents'] = 1
                    print(f"    Created NAME_CHANGE record: {hybrid_name}, crop: {row_dict['Crop']}, is_merged = True")
                    all_years_data.append(row_dict)
                
                processed_districts.add(single_district)
                merging_happened_this_year = True
        
        print(f"  Merging happened this year: {merging_happened_this_year}")
        
        # Handle ALL remaining districts that weren't processed (unmerged districts)
        unprocessed_districts = all_districts_in_data - processed_districts
        print(f"  Unprocessed districts: {len(unprocessed_districts)}")
        
        for district in unprocessed_districts:
            district_data = year_data[year_data[district_col] == district]
            for _, row in district_data.iterrows():
                row_dict = row.copy().to_dict()
                row_dict['is_merged'] = False
                row_dict['constituent_districts'] = [district]
                row_dict['num_constituents'] = 1
                all_years_data.append(row_dict)
    
    # Convert to DataFrame
    print(f"Converting {len(all_years_data)} records to DataFrame...")
    harmonized_df = pd.DataFrame(all_years_data)
    
    # Debug: Check is_merged column before any processing
    if 'is_merged' in harmonized_df.columns:
        merged_count_before = harmonized_df['is_merged'].sum()
        print(f"Before processing: {merged_count_before} merged records")
        print(f"is_merged value counts: {harmonized_df['is_merged'].value_counts()}")
    else:
        print("ERROR: is_merged column not found in DataFrame!")
        print(f"Available columns: {harmonized_df.columns.tolist()}")
    
    # Final check
    if 'is_merged' in harmonized_df.columns:
        merged_count = harmonized_df['is_merged'].sum()
        print(f"\nFinal result: {merged_count} merged records out of {len(harmonized_df)} total")
    
    # Ensure proper column order (similar to original)
    original_cols = [col for col in crop_df.columns if col in harmonized_df.columns]
    status_cols = ['is_merged', 'constituent_districts', 'num_constituents']
    harmonized_df = harmonized_df[original_cols + status_cols]
    
    return harmonized_df

def validate_year_by_year(original_df, harmonized_df, year_col='Year'):
    """
    Validate that aggregation preserved totals for each year
    Focuses on the specific crop data columns
    """
    # Specific columns to validate for your data
    validate_cols = ['Area Planted: ha', 'Area Harvested: ha', 'Quantity Produced: MT']
    
    validation_results = {}
    
    for year in original_df[year_col].unique():
        orig_year_data = original_df[original_df[year_col] == year]
        harm_year_data = harmonized_df[harmonized_df[year_col] == year]
        
        # Only validate columns that exist in both datasets
        valid_cols = [col for col in validate_cols if col in orig_year_data.columns and col in harm_year_data.columns]
        
        if valid_cols:
            orig_totals = orig_year_data[valid_cols].sum()
            harm_totals = harm_year_data[valid_cols].sum()
            totals_match = np.allclose(orig_totals.values, harm_totals.values, rtol=1e-10)
        else:
            orig_totals = pd.Series(dtype=float)
            harm_totals = pd.Series(dtype=float)
            totals_match = True
        
        validation_results[year] = {
            'original_records': len(orig_year_data),
            'harmonized_records': len(harm_year_data),
            'original_totals': orig_totals.to_dict() if not orig_totals.empty else {},
            'harmonized_totals': harm_totals.to_dict() if not harm_totals.empty else {},
            'totals_match': totals_match,
            'records_with_constituents': len(harm_year_data[harm_year_data['num_constituents'] > 1]) if 'num_constituents' in harm_year_data.columns else 0
        }
    
    return validation_results

def diagnose_merged_dis_column(hybrid_df):
    """
    Diagnostic function to understand the structure of your merged_dis column
    """
    print("=== Merged Districts Column Diagnosis ===")
    print(f"Total rows: {len(hybrid_df)}")
    
    # Check for None/NaN values
    null_count = hybrid_df['merged_dis'].isna().sum()
    print(f"Null/NaN values: {null_count}")
    
    # Check data types
    print(f"Data types present: {hybrid_df['merged_dis'].apply(type).value_counts()}")
    
    # Show some examples
    print("\n=== Sample values ===")
    for i, (idx, row) in enumerate(hybrid_df.head(10).iterrows()):
        print(f"{row['name_state']}: {repr(row['merged_dis'])} (type: {type(row['merged_dis'])})")
    
    # Check for empty strings
    empty_string_count = (hybrid_df['merged_dis'] == '').sum()
    print(f"\nEmpty strings: {empty_string_count}")
    
    return hybrid_df['merged_dis'].value_counts()

def create_temporally_aware_harmonized_dataset(hybrid_shapefile_path, crop_data_path, 
                                             district_col='Admin 2', year_col='Year'):
    """
    Create harmonized dataset with year-by-year presence checking
    
    Parameters:
    -----------
    hybrid_shapefile_path : str
        Path to the hybrid boundary shapefile
    crop_data_path : str
        Path to the crop data CSV
    district_col : str
        Name of district column in crop data (default: 'Admin 2')
    year_col : str
        Name of year column in crop data (default: 'Year')
    
    Returns:
    --------
    final_data : pd.DataFrame
        Harmonized crop data
    validation : dict
        Validation results by year
    merging_rules : dict
        Dictionary of merging rules used
    """
    
    # Load data
    print("=== Loading data ===")
    hybrid_gdf = gpd.read_file(hybrid_shapefile_path)
    crop_df = pd.read_csv(crop_data_path)
    
    print(f"Loaded {len(hybrid_gdf)} hybrid districts")
    print(f"Loaded {len(crop_df)} crop data records")
    print(f"Years in data: {sorted(crop_df[year_col].unique())}")
    
    # Filter to only include years 2016-2022
    print("\n=== Filtering to years 2016-2022 ===")
    original_count = len(crop_df)
    crop_df = crop_df[(crop_df[year_col] >= 2016) & (crop_df[year_col] <= 2022)]
    filtered_count = len(crop_df)
    
    print(f"Filtered from {original_count} to {filtered_count} records")
    print(f"Years after filtering: {sorted(crop_df[year_col].unique())}")
    print(f"Crops in data: {sorted(crop_df['Source crop'].unique())}")
    
    if len(crop_df) == 0:
        raise ValueError("No data remains after filtering to 2016-2022. Check your year column and data.")
    
    # Diagnose the data first
    print("\n=== Diagnosing hybrid boundary data ===")
    diagnose_merged_dis_column(hybrid_gdf)
    
    # Parse merging rules with improved error handling
    print("\n=== Parsing merging rules ===")
    merging_rules = parse_merging_rules(hybrid_gdf)
    
    print(f"Found {len(merging_rules)} hybrid districts")
    
    # Analyze the merging structure
    constituent_counts, merged_districts = analyze_merging_rules(merging_rules)
    
    # Quick data check - what districts are in your crop data?
    crop_districts = set(crop_df[district_col].unique())
    print(f"\nCrop data contains {len(crop_districts)} unique districts")
    
    # Check for potential district name matching issues
    all_constituents = set()
    for constituents in merging_rules.values():
        all_constituents.update(constituents)
    
    print(f"Merging rules reference {len(all_constituents)} unique district names")
    
    # Find potential mismatches
    missing_from_crop = all_constituents - crop_districts
    if missing_from_crop:
        print(f"Warning: {len(missing_from_crop)} districts in merging rules not found in crop data")
        print("Sample missing districts:", list(missing_from_crop)[:5])
    
    extra_in_crop = crop_districts - all_constituents
    if extra_in_crop:
        print(f"Note: {len(extra_in_crop)} districts in crop data not referenced in merging rules")
        print("Sample extra districts:", list(extra_in_crop)[:5])
    
    # Aggregate year by year
    print("\n=== Aggregating data by year ===")
    harmonized_data = aggregate_by_year_presence(crop_df, merging_rules, district_col, year_col)
    
    # Validate
    print("\n=== Validating results ===")
    validation = validate_year_by_year(crop_df, harmonized_data, year_col)
    
    # Print validation summary
    print("\n=== Validation Results ===")
    for year, results in validation.items():
        print(f"Year {year}: {results['original_records']} -> {results['harmonized_records']} records, "
              f"totals match: {results['totals_match']}, "
              f"merged records: {results['records_with_constituents']}")
    
    # Clean up the output but keep the merging status indicator
    final_data = harmonized_data.drop(['constituent_districts', 'num_constituents'], axis=1, errors='ignore')
    
    # Show summary of merging
    merged_count = final_data['is_merged'].sum() if 'is_merged' in final_data.columns else 0
    total_count = len(final_data)
    print(f"\nMerging summary: {merged_count} merged records, {total_count - merged_count} unmerged records out of {total_count} total")
    
    # Save
    output_path = '../../data/temporally_harmonized_crop_data_072425.csv'
    final_data.to_csv(output_path, index=False)
    print(f"\nSaved harmonized data to: {output_path}")
    
    return final_data, validation, merging_rules

# %%
# Run the harmonization with correct column names
harmonized_data, validation, merging_rules = create_temporally_aware_harmonized_dataset(
    shp_path, 
    ag_stats_path,
    district_col='Admin 2',  # District column in your crop data
    year_col='Year'         # Year column in your crop data
)

# Optional: Save additional outputs for inspection
print("\n=== Additional outputs ===")

# Save merging rules for reference
merging_df = pd.DataFrame([
    {'hybrid_district': hybrid, 'constituent_districts': ', '.join(constituents)}
    for hybrid, constituents in merging_rules.items()
])
merging_df.to_csv('../../data/merging_rules.csv', index=False)
print("Saved merging rules to: merging_rules.csv")

# Save validation results
validation_df = pd.DataFrame(validation).T
validation_df.to_csv('../../data/validation_results.csv')
print("Saved validation results to: validation_results.csv")

# Show sample of harmonized data
print("\n=== Sample of harmonized data ===")
print(f"Shape: {harmonized_data.shape}")
print(f"Columns: {list(harmonized_data.columns)}")
print("\nFirst few rows:")
print(harmonized_data.head())

print("\nProcess complete!")
# Out:
# === Loading data ===
# Loaded 676 hybrid districts
# Loaded 365989 crop data records
# Years in data: [np.int64(1997), np.int64(1998), np.int64(1999), np.int64(2000), np.int64(2001), np.int64(2002), np.int64(2003), np.int64(2004), np.int64(2005), np.int64(2006), np.int64(2007), np.int64(2008), np.int64(2009), np.int64(2010), np.int64(2011), np.int64(2012), np.int64(2013), np.int64(2014), np.int64(2015), np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022)]
#
# === Filtering to years 2016-2022 ===
# Filtered from 365989 to 117625 records
# Years after filtering: [np.int64(2016), np.int64(2017), np.int64(2018), np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022)]
# Crops in data: ['Arecanut', 'Arhar/Tur', 'Bajra', 'Banana', 'Barley', 'Black pepper', 'Cardamom', 'Cashewnut', 'Castor seed', 'Coconut', 'Coriander', 'Cotton(lint)', 'Cowpea(Lobia)', 'Dry chillies', 'Garlic', 'Ginger', 'Groundnut', 'Guar seed', 'Horse-gram', 'Jowar', 'Jute', 'Khesari', 'Linseed', 'Maize', 'Masoor', 'Mesta', 'Moong(Green Gram)', 'Moth', 'Niger seed', 'Onion', 'Other Cereals', 'Peas & beans (Pulses)', 'Potato', 'Ragi', 'Rapeseed &Mustard', 'Rice', 'Safflower', 'Sannhamp', 'Sesamum', 'Small millets', 'Soyabean', 'Sugarcane', 'Sweet potato', 'Tapioca', 'Tobacco', 'Turmeric', 'Urad', 'Wheat']
#
# === Diagnosing hybrid boundary data ===
# === Merged Districts Column Diagnosis ===
# Total rows: 676
# Null/NaN values: 604
# Data types present: merged_dis
# <class 'NoneType'>    604
# <class 'str'>          72
# Name: count, dtype: int64
#
# === Sample values ===
# Lahaul and Spiti (HP): None (type: <class 'NoneType'>)
# Kinnaur (HP): None (type: <class 'NoneType'>)
# Kullu (HP): None (type: <class 'NoneType'>)
# Chamba (HP): None (type: <class 'NoneType'>)
# Kangra (HP): None (type: <class 'NoneType'>)
# Una (HP): None (type: <class 'NoneType'>)
# Hamirpur (HP): None (type: <class 'NoneType'>)
# Mandi (HP): None (type: <class 'NoneType'>)
# Bilaspur (HP): None (type: <class 'NoneType'>)
# Solan (HP): None (type: <class 'NoneType'>)
#
# Empty strings: 0
#
# === Parsing merging rules ===
# Found 676 hybrid districts
# === Merging Rules Analysis ===
# Districts by number of constituents:
#   1 constituent(s): 608 districts
#   2 constituent(s): 46 districts
#   3 constituent(s): 12 districts
#   4 constituent(s): 4 districts
#   5 constituent(s): 3 districts
#   6 constituent(s): 1 districts
#   7 constituent(s): 1 districts
#   8 constituent(s): 1 districts
#
# Total merged districts: 68
#
# Sample merged districts:
#   Chhindwara (MP): ['Chhindwara (MP)', 'Pandhurna (MP)']
#   Satna (MP): ['Maihar (MP)', 'Satna (MP)']
#   Naguar (RJ): ['Didwana-Kuchaman (RJ)', 'Nagaur (RJ)']
#   Rewa (MP): ['Mauganj (MP)', 'Rewa (MP)']
#   Barmer (RJ): ['Balotra (RJ)', 'Barmer (RJ)']
#   Bharatpur (RJ): ['Bharatpur (RJ)', 'Deeg (RJ)']
#   Udaipur (RJ): ['Salumbar (RJ)', 'Udaipur (RJ)']
#   Jaipur (RJ), Alwar (RJ): ['Alwar (RJ)', 'Dudu (RJ)', 'Jaipur (RJ)', 'Jaipur(Rural) (RJ)', 'Kherthal-Tijara (RJ)', 'Kotputli-Behror (RJ)']
#   Ajmer (RJ), Pali (RJ), Tonk (RJ): ['Ajmer (RJ)', 'Beaware (RJ)', 'Kekri (RJ)', 'Pali (RJ)', 'Tonk (RJ)']
#   Jalore (RJ): ['Jalora (RJ)', 'Sanchore (RJ)']
#
# Crop data contains 745 unique districts
# Merging rules reference 788 unique district names
# Warning: 52 districts in merging rules not found in crop data
# Sample missing districts: ['Neem Ka Thana (RJ)', 'Kherthal-Tijara (RJ)', 'Beaware (RJ)', 'Balotra (RJ)', 'Kakching (MN)']
# Note: 9 districts in crop data not referenced in merging rules
# Sample extra districts: ['Daman (DA)', 'Daman (DD)', 'Delhi_Total (DL)', 'Diu (DA)', 'Jalore (RJ)']
#
# === Aggregating data by year ===
# Found 68 districts that require actual merging
#   Chhindwara (MP): ['Chhindwara (MP)', 'Pandhurna (MP)']
#   Satna (MP): ['Maihar (MP)', 'Satna (MP)']
#   Naguar (RJ): ['Didwana-Kuchaman (RJ)', 'Nagaur (RJ)']
#   Rewa (MP): ['Mauganj (MP)', 'Rewa (MP)']
#   Barmer (RJ): ['Balotra (RJ)', 'Barmer (RJ)']
#
# Total districts in crop data: 745
# Sample crop districts: ['Rohtak (HR)', 'Sehore (MP)', 'Peddapalli (TG)', 'Lohardaga (JH)', 'Ramban (JK)', 'Biswanath (AS)', 'Kishtwar (JK)', 'Kamle (AR)', 'Sidhi (MP)', 'Botad (GJ)']
# Districts in both merging rules and crop data: 146
# Sample overlapping districts: ['Eluru (AP)', 'Vellore (TN)', 'Tirunelveli (TN)', 'Peddapalli (TG)', 'Bhilwara (RJ)', 'Chhindwara (MP)', 'Jaipur (RJ)', 'Kamle (AR)', 'Prakasam (AP)', 'Sri Sathya Sai (AP)']
# Processing year 2016...
#   Hybrid Chhindwara (MP): 1 of 2 constituents present
#     Present: ['Chhindwara (MP)']
#   Hybrid Satna (MP): 1 of 2 constituents present
#     Present: ['Satna (MP)']
#   Hybrid Naguar (RJ): 1 of 2 constituents present
#     Present: ['Nagaur (RJ)']
#   Hybrid Rewa (MP): 1 of 2 constituents present
#     Present: ['Rewa (MP)']
#   Hybrid Barmer (RJ): 1 of 2 constituents present
#     Present: ['Barmer (RJ)']
#   Hybrid Bharatpur (RJ): 1 of 2 constituents present
#     Present: ['Bharatpur (RJ)']
#   Hybrid Udaipur (RJ): 1 of 2 constituents present
#     Present: ['Udaipur (RJ)']
#   Hybrid Jaipur (RJ), Alwar (RJ): 2 of 6 constituents present
#     Present: ['Alwar (RJ)', 'Jaipur (RJ)']
#     -> MERGING 2 districts
#       Processing crop group: Arhar/Tur with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Arhar/Tur, is_merged = True
#       Processing crop group: Bajra with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Bajra, is_merged = True
#       Processing crop group: Barley with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Barley, is_merged = True
#       Processing crop group: Castor seed with 1 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Castor seed, is_merged = True
#       Processing crop group: Coriander with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Coriander, is_merged = True
#       Processing crop group: Cotton(lint) with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Cotton(lint), is_merged = True
#       Processing crop group: Dry chillies with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Dry chillies, is_merged = True
#       Processing crop group: Garlic with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Garlic, is_merged = True
#       Processing crop group: Groundnut with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Groundnut, is_merged = True
#       Processing crop group: Guar seed with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Guar seed, is_merged = True
#       Processing crop group: Jowar with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Jowar, is_merged = True
#       Processing crop group: Linseed with 1 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Linseed, is_merged = True
#       Processing crop group: Maize with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Maize, is_merged = True
#       Processing crop group: Masoor with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Masoor, is_merged = True
#       Processing crop group: Moong(Green Gram) with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Moong(Green Gram), is_merged = True
#       Processing crop group: Moth with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Moth, is_merged = True
#       Processing crop group: Onion with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Onion, is_merged = True
#       Processing crop group: Peas & beans (Pulses) with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Peas & beans (Pulses), is_merged = True
#       Processing crop group: Potato with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Potato, is_merged = True
#       Processing crop group: Rapeseed &Mustard with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Rapeseed &Mustard, is_merged = True
#       Processing crop group: Rice with 1 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Rice, is_merged = True
#       Processing crop group: Sannhamp with 1 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Sannhamp, is_merged = True
#       Processing crop group: Sesamum with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Sesamum, is_merged = True
#       Processing crop group: Small millets with 1 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Small millets, is_merged = True
#       Processing crop group: Soyabean with 1 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Soyabean, is_merged = True
#       Processing crop group: Sugarcane with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Sugarcane, is_merged = True
#       Processing crop group: Sweet potato with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Sweet potato, is_merged = True
#       Processing crop group: Tobacco with 1 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Tobacco, is_merged = True
#       Processing crop group: Urad with 1 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Urad, is_merged = True
#       Processing crop group: Wheat with 2 records
#     Created merged record: Jaipur (RJ), Alwar (RJ), crop: Wheat, is_merged = True
#   Hybrid Ajmer (RJ), Pali (RJ), Tonk (RJ): 3 of 5 constituents present
#     Present: ['Ajmer (RJ)', 'Pali (RJ)', 'Tonk (RJ)']
#     -> MERGING 3 districts
#       Processing crop group: Arhar/Tur with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Arhar/Tur, is_merged = True
#       Processing crop group: Bajra with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Bajra, is_merged = True
#       Processing crop group: Barley with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Barley, is_merged = True
#       Processing crop group: Castor seed with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Castor seed, is_merged = True
#       Processing crop group: Coriander with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Coriander, is_merged = True
#       Processing crop group: Cotton(lint) with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Cotton(lint), is_merged = True
#       Processing crop group: Dry chillies with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Dry chillies, is_merged = True
#       Processing crop group: Garlic with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Garlic, is_merged = True
#       Processing crop group: Groundnut with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Groundnut, is_merged = True
#       Processing crop group: Guar seed with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Guar seed, is_merged = True
#       Processing crop group: Jowar with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Jowar, is_merged = True
#       Processing crop group: Linseed with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Linseed, is_merged = True
#       Processing crop group: Maize with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Maize, is_merged = True
#       Processing crop group: Masoor with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Masoor, is_merged = True
#       Processing crop group: Moong(Green Gram) with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Moong(Green Gram), is_merged = True
#       Processing crop group: Moth with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Moth, is_merged = True
#       Processing crop group: Onion with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Onion, is_merged = True
#       Processing crop group: Peas & beans (Pulses) with 2 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Peas & beans (Pulses), is_merged = True
#       Processing crop group: Potato with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Potato, is_merged = True
#       Processing crop group: Rapeseed &Mustard with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Rapeseed &Mustard, is_merged = True
#       Processing crop group: Rice with 2 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Rice, is_merged = True
#       Processing crop group: Sannhamp with 2 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Sannhamp, is_merged = True
#       Processing crop group: Sesamum with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Sesamum, is_merged = True
#       Processing crop group: Small millets with 1 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Small millets, is_merged = True
#       Processing crop group: Soyabean with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Soyabean, is_merged = True
#       Processing crop group: Sugarcane with 2 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Sugarcane, is_merged = True
#       Processing crop group: Sweet potato with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Sweet potato, is_merged = True
#       Processing crop group: Tobacco with 1 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Tobacco, is_merged = True
#       Processing crop group: Turmeric with 1 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Turmeric, is_merged = True
#       Processing crop group: Urad with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Urad, is_merged = True
#       Processing crop group: Wheat with 3 records
#     Created merged record: Ajmer (RJ), Pali (RJ), Tonk (RJ), crop: Wheat, is_merged = True
#   Hybrid Jalore (RJ): 0 of 2 constituents present
#   Hybrid Bhilwara (RJ): 1 of 2 constituents present
#     Present: ['Bhilwara (RJ)']
#   Hybrid Sawai Madhopour (RJ), Karauli (RJ): 2 of 3 constituents present
#     Present: ['Karauli (RJ)', 'Sawai Madhopur (RJ)']
#     -> MERGING 2 districts
#       Processing crop group: Arhar/Tur with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Arhar/Tur, is_merged = True
#       Processing crop group: Bajra with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Bajra, is_merged = True
#       Processing crop group: Banana with 1 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Banana, is_merged = True
#       Processing crop group: Barley with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Barley, is_merged = True
#       Processing crop group: Coriander with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Coriander, is_merged = True
#       Processing crop group: Dry chillies with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Dry chillies, is_merged = True
#       Processing crop group: Garlic with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Garlic, is_merged = True
#       Processing crop group: Groundnut with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Groundnut, is_merged = True
#       Processing crop group: Guar seed with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Guar seed, is_merged = True
#       Processing crop group: Jowar with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Jowar, is_merged = True
#       Processing crop group: Linseed with 1 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Linseed, is_merged = True
#       Processing crop group: Maize with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Maize, is_merged = True
#       Processing crop group: Masoor with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Masoor, is_merged = True
#       Processing crop group: Moong(Green Gram) with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Moong(Green Gram), is_merged = True
#       Processing crop group: Moth with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Moth, is_merged = True
#       Processing crop group: Onion with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Onion, is_merged = True
#       Processing crop group: Peas & beans (Pulses) with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Peas & beans (Pulses), is_merged = True
#       Processing crop group: Potato with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Potato, is_merged = True
#       Processing crop group: Rapeseed &Mustard with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Rapeseed &Mustard, is_merged = True
#       Processing crop group: Rice with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Rice, is_merged = True
#       Processing crop group: Sannhamp with 1 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Sannhamp, is_merged = True
#       Processing crop group: Sesamum with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Sesamum, is_merged = True
#       Processing crop group: Soyabean with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Soyabean, is_merged = True
#       Processing crop group: Sugarcane with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Sugarcane, is_merged = True
#       Processing crop group: Sweet potato with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Sweet potato, is_merged = True
#       Processing crop group: Tobacco with 1 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Tobacco, is_merged = True
#       Processing crop group: Urad with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Urad, is_merged = True
#       Processing crop group: Wheat with 2 records
#     Created merged record: Sawai Madhopour (RJ), Karauli (RJ), crop: Wheat, is_merged = True
#   Hybrid Jodhpur (RJ): 1 of 3 constituents present
#     Present: ['Jodhpur (RJ)']
#   Hybrid Sikar (RJ), Jhunjhunu (RJ): 2 of 3 constituents present
#     Present: ['Jhunjhunu (RJ)', 'Sikar (RJ)']
#     -> MERGING 2 districts
#       Processing crop group: Arhar/Tur with 1 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Arhar/Tur, is_merged = True
#       Processing crop group: Bajra with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Bajra, is_merged = True
#       Processing crop group: Barley with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Barley, is_merged = True
#       Processing crop group: Castor seed with 1 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Castor seed, is_merged = True
#       Processing crop group: Coriander with 1 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Coriander, is_merged = True
#       Processing crop group: Cotton(lint) with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Cotton(lint), is_merged = True
#       Processing crop group: Dry chillies with 1 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Dry chillies, is_merged = True
#       Processing crop group: Garlic with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Garlic, is_merged = True
#       Processing crop group: Groundnut with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Groundnut, is_merged = True
#       Processing crop group: Guar seed with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Guar seed, is_merged = True
#       Processing crop group: Jowar with 1 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Jowar, is_merged = True
#       Processing crop group: Maize with 1 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Maize, is_merged = True
#       Processing crop group: Masoor with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Masoor, is_merged = True
#       Processing crop group: Moong(Green Gram) with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Moong(Green Gram), is_merged = True
#       Processing crop group: Moth with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Moth, is_merged = True
#       Processing crop group: Onion with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Onion, is_merged = True
#       Processing crop group: Peas & beans (Pulses) with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Peas & beans (Pulses), is_merged = True
#       Processing crop group: Potato with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Potato, is_merged = True
#       Processing crop group: Rapeseed &Mustard with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Rapeseed &Mustard, is_merged = True
#       Processing crop group: Sesamum with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Sesamum, is_merged = True
#       Processing crop group: Soyabean with 1 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Soyabean, is_merged = True
#       Processing crop group: Sugarcane with 1 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Sugarcane, is_merged = True
#       Processing crop group: Sweet potato with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Sweet potato, is_merged = True
#       Processing crop group: Urad with 1 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Urad, is_merged = True
#       Processing crop group: Wheat with 2 records
#     Created merged record: Sikar (RJ), Jhunjhunu (RJ), crop: Wheat, is_merged = True
#   Hybrid Sri Ganganagar (RJ), Bikaner (RJ): 2 of 3 constituents present
#     Present: ['Bikaner (RJ)', 'Sri Ganganagar (RJ)']
#     -> MERGING 2 districts
#       Processing crop group: Arhar/Tur with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Arhar/Tur, is_merged = True
#       Processing crop group: Bajra with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Bajra, is_merged = True
#       Processing crop group: Barley with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Barley, is_merged = True
#       Processing crop group: Castor seed with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Castor seed, is_merged = True
#       Processing crop group: Coriander with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Coriander, is_merged = True
#       Processing crop group: Cotton(lint) with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Cotton(lint), is_merged = True
#       Processing crop group: Dry chillies with 1 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Dry chillies, is_merged = True
#       Processing crop group: Garlic with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Garlic, is_merged = True
#       Processing crop group: Groundnut with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Groundnut, is_merged = True
#       Processing crop group: Guar seed with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Guar seed, is_merged = True
#       Processing crop group: Jowar with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Jowar, is_merged = True
#       Processing crop group: Linseed with 1 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Linseed, is_merged = True
#       Processing crop group: Maize with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Maize, is_merged = True
#       Processing crop group: Masoor with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Masoor, is_merged = True
#       Processing crop group: Moong(Green Gram) with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Moong(Green Gram), is_merged = True
#       Processing crop group: Moth with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Moth, is_merged = True
#       Processing crop group: Onion with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Onion, is_merged = True
#       Processing crop group: Peas & beans (Pulses) with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Peas & beans (Pulses), is_merged = True
#       Processing crop group: Potato with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Potato, is_merged = True
#       Processing crop group: Rapeseed &Mustard with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Rapeseed &Mustard, is_merged = True
#       Processing crop group: Rice with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Rice, is_merged = True
#       Processing crop group: Sesamum with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Sesamum, is_merged = True
#       Processing crop group: Sugarcane with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Sugarcane, is_merged = True
#       Processing crop group: Urad with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Urad, is_merged = True
#       Processing crop group: Wheat with 2 records
#     Created merged record: Sri Ganganagar (RJ), Bikaner (RJ), crop: Wheat, is_merged = True
#   Hybrid Srikakulam (AP), Vizianagaram (AP): 2 of 3 constituents present
#     Present: ['Srikakulam (AP)', 'Vizianagaram (AP)']
#     -> MERGING 2 districts
#       Processing crop group: Arecanut with 1 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Arecanut, is_merged = True
#       Processing crop group: Arhar/Tur with 3 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Arhar/Tur, is_merged = True
#       Processing crop group: Bajra with 2 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Bajra, is_merged = True
#       Processing crop group: Banana with 2 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Banana, is_merged = True
#       Processing crop group: Cashewnut with 2 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Cashewnut, is_merged = True
#       Processing crop group: Coconut with 2 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Coconut, is_merged = True
#       Processing crop group: Cotton(lint) with 3 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Cotton(lint), is_merged = True
#       Processing crop group: Dry chillies with 4 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Dry chillies, is_merged = True
#       Processing crop group: Ginger with 2 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Ginger, is_merged = True
#       Processing crop group: Groundnut with 4 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Groundnut, is_merged = True
#       Processing crop group: Horse-gram with 2 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Horse-gram, is_merged = True
#       Processing crop group: Jowar with 3 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Jowar, is_merged = True
#       Processing crop group: Maize with 4 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Maize, is_merged = True
#       Processing crop group: Mesta with 2 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Mesta, is_merged = True
#       Processing crop group: Moong(Green Gram) with 4 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Moong(Green Gram), is_merged = True
#       Processing crop group: Niger seed with 1 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Niger seed, is_merged = True
#       Processing crop group: Onion with 4 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Onion, is_merged = True
#       Processing crop group: Ragi with 4 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Ragi, is_merged = True
#       Processing crop group: Rice with 4 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Rice, is_merged = True
#       Processing crop group: Sesamum with 4 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Sesamum, is_merged = True
#       Processing crop group: Small millets with 2 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Small millets, is_merged = True
#       Processing crop group: Sugarcane with 2 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Sugarcane, is_merged = True
#       Processing crop group: Sweet potato with 3 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Sweet potato, is_merged = True
#       Processing crop group: Tapioca with 4 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Tapioca, is_merged = True
#       Processing crop group: Tobacco with 1 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Tobacco, is_merged = True
#       Processing crop group: Turmeric with 2 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Turmeric, is_merged = True
#       Processing crop group: Urad with 4 records
#     Created merged record: Srikakulam (AP), Vizianagaram (AP), crop: Urad, is_merged = True
#   Hybrid YSR Kadapa (AP), Chittoor (AP), Nellore (AP): 3 of 5 constituents present
#     Present: ['Chittoor (AP)', 'Nellore (AP)', 'YSR Kadapa (AP)']
#     -> MERGING 3 districts
#       Processing crop group: Arhar/Tur with 5 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Arhar/Tur, is_merged = True
#       Processing crop group: Bajra with 6 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Bajra, is_merged = True
#       Processing crop group: Banana with 3 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Banana, is_merged = True
#       Processing crop group: Cashewnut with 3 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Cashewnut, is_merged = True
#       Processing crop group: Castor seed with 3 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Castor seed, is_merged = True
#       Processing crop group: Coconut with 3 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Coconut, is_merged = True
#       Processing crop group: Coriander with 3 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Coriander, is_merged = True
#       Processing crop group: Cotton(lint) with 6 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Cotton(lint), is_merged = True
#       Processing crop group: Cowpea(Lobia) with 5 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Cowpea(Lobia), is_merged = True
#       Processing crop group: Dry chillies with 4 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Dry chillies, is_merged = True
#       Processing crop group: Ginger with 1 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Ginger, is_merged = True
#       Processing crop group: Groundnut with 6 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Groundnut, is_merged = True
#       Processing crop group: Guar seed with 1 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Guar seed, is_merged = True
#       Processing crop group: Horse-gram with 5 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Horse-gram, is_merged = True
#       Processing crop group: Jowar with 5 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Jowar, is_merged = True
#       Processing crop group: Linseed with 1 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Linseed, is_merged = True
#       Processing crop group: Maize with 6 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Maize, is_merged = True
#       Processing crop group: Moong(Green Gram) with 6 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Moong(Green Gram), is_merged = True
#       Processing crop group: Onion with 5 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Onion, is_merged = True
#       Processing crop group: Potato with 3 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Potato, is_merged = True
#       Processing crop group: Ragi with 6 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Ragi, is_merged = True
#       Processing crop group: Rapeseed &Mustard with 2 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Rapeseed &Mustard, is_merged = True
#       Processing crop group: Rice with 6 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Rice, is_merged = True
#       Processing crop group: Safflower with 1 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Safflower, is_merged = True
#       Processing crop group: Sesamum with 6 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Sesamum, is_merged = True
#       Processing crop group: Small millets with 4 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Small millets, is_merged = True
#       Processing crop group: Soyabean with 1 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Soyabean, is_merged = True
#       Processing crop group: Sugarcane with 3 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Sugarcane, is_merged = True
#       Processing crop group: Sweet potato with 5 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Sweet potato, is_merged = True
#       Processing crop group: Tapioca with 1 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Tapioca, is_merged = True
#       Processing crop group: Tobacco with 3 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Tobacco, is_merged = True
#       Processing crop group: Turmeric with 3 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Turmeric, is_merged = True
#       Processing crop group: Urad with 6 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Urad, is_merged = True
#       Processing crop group: Wheat with 1 records
#     Created merged record: YSR Kadapa (AP), Chittoor (AP), Nellore (AP), crop: Wheat, is_merged = True
#   Hybrid West Godavari (AP): 1 of 2 constituents present
#     Present: ['West Godavari (AP)']
#   Hybrid Kurnool (AP): 1 of 2 constituents present
#     Present: ['Kurnool (AP)']
#   Hybrid Krishna (AP): 1 of 2 constituents present
#     Present: ['Krishna (AP)']
#   Hybrid Guntur (AP), Prakasam (AP): 2 of 4 constituents present
#     Present: ['Guntur (AP)', 'Prakasam (AP)']
#     -> MERGING 2 districts
#       Processing crop group: Arhar/Tur with 4 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Arhar/Tur, is_merged = True
#       Processing crop group: Bajra with 3 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Bajra, is_merged = True
#       Processing crop group: Banana with 2 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Banana, is_merged = True
#       Processing crop group: Cashewnut with 2 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Cashewnut, is_merged = True
#       Processing crop group: Castor seed with 4 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Castor seed, is_merged = True
#       Processing crop group: Coconut with 2 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Coconut, is_merged = True
#       Processing crop group: Coriander with 1 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Coriander, is_merged = True
#       Processing crop group: Cotton(lint) with 4 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Cotton(lint), is_merged = True
#       Processing crop group: Cowpea(Lobia) with 2 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Cowpea(Lobia), is_merged = True
#       Processing crop group: Dry chillies with 4 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Dry chillies, is_merged = True
#       Processing crop group: Groundnut with 4 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Groundnut, is_merged = True
#       Processing crop group: Horse-gram with 2 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Horse-gram, is_merged = True
#       Processing crop group: Jowar with 4 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Jowar, is_merged = True
#       Processing crop group: Maize with 4 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Maize, is_merged = True
#       Processing crop group: Moong(Green Gram) with 4 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Moong(Green Gram), is_merged = True
#       Processing crop group: Onion with 4 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Onion, is_merged = True
#       Processing crop group: Potato with 1 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Potato, is_merged = True
#       Processing crop group: Ragi with 3 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Ragi, is_merged = True
#       Processing crop group: Rapeseed &Mustard with 2 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Rapeseed &Mustard, is_merged = True
#       Processing crop group: Rice with 4 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Rice, is_merged = True
#       Processing crop group: Sesamum with 4 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Sesamum, is_merged = True
#       Processing crop group: Small millets with 2 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Small millets, is_merged = True
#       Processing crop group: Soyabean with 2 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Soyabean, is_merged = True
#       Processing crop group: Sugarcane with 2 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Sugarcane, is_merged = True
#       Processing crop group: Sweet potato with 2 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Sweet potato, is_merged = True
#       Processing crop group: Tobacco with 3 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Tobacco, is_merged = True
#       Processing crop group: Turmeric with 3 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Turmeric, is_merged = True
#       Processing crop group: Urad with 4 records
#     Created merged record: Guntur (AP), Prakasam (AP), crop: Urad, is_merged = True
#   Hybrid East Godavari (AP): 1 of 3 constituents present
#     Present: ['East Godavari (AP)']
#   Hybrid Visakhapatnam (AP): 1 of 3 constituents present
#     Present: ['Visakhapatnam (AP)']
#   Hybrid Anantapur (AP): 1 of 2 constituents present
#     Present: ['Anantapur (AP)']
#   Hybrid Rajnandgaon (CG): 1 of 2 constituents present
#     Present: ['Rajnandgaon (CG)']
#   Hybrid Baksa (AS): 1 of 2 constituents present
#     Present: ['Baksa (AS)']
#   Hybrid Tuensang (NL): 1 of 3 constituents present
#     Present: ['Tuensang (NL)']
#   Hybrid West Sikkim (SK): 1 of 2 constituents present
#     Present: ['Gyalshing (SK)']
#   Hybrid East Sikkim (SK): 1 of 2 constituents present
#     Present: ['Gangtok (SK)']
#   Hybrid Kohima (NL): 1 of 2 constituents present
#     Present: ['Kohima (NL)']
#   Hybrid Dimapur (NL): 1 of 3 constituents present
#     Present: ['Dimapur (NL)']
#   Hybrid West Khasi Hills (ML): 1 of 2 constituents present
#     Present: ['West Khasi Hills (ML)']
#   Hybrid Raigarh (CG), Baloda Bazar (CG): 2 of 3 constituents present
#     Present: ['Baloda Bazar (CG)', 'Raigarh (CG)']
#     -> MERGING 2 districts
#       Processing crop group: Arhar/Tur with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Arhar/Tur, is_merged = True
#       Processing crop group: Bajra with 1 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Bajra, is_merged = True
#       Processing crop group: Banana with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Banana, is_merged = True
#       Processing crop group: Coriander with 1 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Coriander, is_merged = True
#       Processing crop group: Cotton(lint) with 1 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Cotton(lint), is_merged = True
#       Processing crop group: Dry chillies with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Dry chillies, is_merged = True
#       Processing crop group: Garlic with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Garlic, is_merged = True
#       Processing crop group: Ginger with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Ginger, is_merged = True
#       Processing crop group: Groundnut with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Groundnut, is_merged = True
#       Processing crop group: Horse-gram with 4 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Horse-gram, is_merged = True
#       Processing crop group: Jowar with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Jowar, is_merged = True
#       Processing crop group: Khesari with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Khesari, is_merged = True
#       Processing crop group: Maize with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Maize, is_merged = True
#       Processing crop group: Masoor with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Masoor, is_merged = True
#       Processing crop group: Mesta with 1 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Mesta, is_merged = True
#       Processing crop group: Moong(Green Gram) with 4 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Moong(Green Gram), is_merged = True
#       Processing crop group: Niger seed with 1 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Niger seed, is_merged = True
#       Processing crop group: Onion with 1 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Onion, is_merged = True
#       Processing crop group: Peas & beans (Pulses) with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Peas & beans (Pulses), is_merged = True
#       Processing crop group: Potato with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Potato, is_merged = True
#       Processing crop group: Rapeseed &Mustard with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Rapeseed &Mustard, is_merged = True
#       Processing crop group: Rice with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Rice, is_merged = True
#       Processing crop group: Safflower with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Safflower, is_merged = True
#       Processing crop group: Sannhamp with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Sannhamp, is_merged = True
#       Processing crop group: Sesamum with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Sesamum, is_merged = True
#       Processing crop group: Small millets with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Small millets, is_merged = True
#       Processing crop group: Soyabean with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Soyabean, is_merged = True
#       Processing crop group: Sugarcane with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Sugarcane, is_merged = True
#       Processing crop group: Sweet potato with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Sweet potato, is_merged = True
#       Processing crop group: Turmeric with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Turmeric, is_merged = True
#       Processing crop group: Urad with 4 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Urad, is_merged = True
#       Processing crop group: Wheat with 2 records
#     Created merged record: Raigarh (CG), Baloda Bazar (CG), crop: Wheat, is_merged = True
#   Hybrid Koriya (CG): 1 of 2 constituents present
#     Present: ['Koriya (CG)']
#   Hybrid Janjgir-Champa (CG): 1 of 2 constituents present
#     Present: ['Janjgir-Champa (CG)']
#   Hybrid Bilaspur (CG): 1 of 2 constituents present
#     Present: ['Bilaspur (CG)']
#   Hybrid Nagapattinam (TN): 1 of 2 constituents present
#     Present: ['Nagapattinam (TN)']
#   Hybrid Ballari (KA): 1 of 2 constituents present
#     Present: ['Ballari (KA)']
#   Hybrid Barpeta (AS): 1 of 2 constituents present
#     Present: ['Barpeta (AS)']
#   Hybrid Kanchipuram (TN): 1 of 2 constituents present
#     Present: ['Kanchipuram (TN)']
#   Hybrid Vellore (TN), Ranipet (TN): 1 of 3 constituents present
#     Present: ['Vellore (TN)']
#   Hybrid Tirunelveli (TN): 1 of 2 constituents present
#     Present: ['Tirunelveli (TN)']
#   Hybrid Villupuram (TN): 1 of 2 constituents present
#     Present: ['Villupuram (TN)']
#   Hybrid Champai (MZ), Aizawl (MZ): 2 of 4 constituents present
#     Present: ['Aizawl (MZ)', 'Champhai (MZ)']
#     -> MERGING 2 districts
#       Processing crop group: Arhar/Tur with 2 records
#     Created merged record: Champai (MZ), Aizawl (MZ), crop: Arhar/Tur, is_merged = True
#       Processing crop group: Cotton(lint) with 1 records
#     Created merged record: Champai (MZ), Aizawl (MZ), crop: Cotton(lint), is_merged = True
#       Processing crop group: Cowpea(Lobia) with 2 records
#     Created merged record: Champai (MZ), Aizawl (MZ), crop: Cowpea(Lobia), is_merged = True
#       Processing crop group: Maize with 3 records
#     Created merged record: Champai (MZ), Aizawl (MZ), crop: Maize, is_merged = True
#       Processing crop group: Potato with 1 records
#     Created merged record: Champai (MZ), Aizawl (MZ), crop: Potato, is_merged = True
#       Processing crop group: Rice with 4 records
#     Created merged record: Champai (MZ), Aizawl (MZ), crop: Rice, is_merged = True
# ...
#       Processing crop group: Maize with 10 records
#     Created merged record: Karimnagar (TG), crop: Maize, is_merged = True
#       Processing crop group: Moong(Green Gram) with 10 records
#     Created merged record: Karimnagar (TG), crop: Moong(Green Gram), is_merged = True
#       Processing crop group: Onion with 4 records
#     Created merged record: Karimnagar (TG), crop: Onion, is_merged = True
#       Processing crop group: Potato with 1 records
#     Created merged record: Karimnagar (TG), crop: Potato, is_merged = True
#       Processing crop group: Ragi with 1 records
#     Created merged record: Karimnagar (TG), crop: Ragi, is_merged = True
#       Processing crop group: Rice with 10 records
#     Created merged record: Karimnagar (TG), crop: Rice, is_merged = True
#       Processing crop group: Safflower with 3 records
#     Created merged record: Karimnagar (TG), crop: Safflower, is_merged = True
#       Processing crop group: Sesamum with 7 records
#     Created merged record: Karimnagar (TG), crop: Sesamum, is_merged = True
#       Processing crop group: Soyabean with 7 records
#     Created merged record: Karimnagar (TG), crop: Soyabean, is_merged = True
#       Processing crop group: Sugarcane with 3 records
#     Created merged record: Karimnagar (TG), crop: Sugarcane, is_merged = True
#       Processing crop group: Sweet potato with 2 records
#     Created merged record: Karimnagar (TG), crop: Sweet potato, is_merged = True
#       Processing crop group: Tobacco with 2 records
#     Created merged record: Karimnagar (TG), crop: Tobacco, is_merged = True
#       Processing crop group: Turmeric with 4 records
#     Created merged record: Karimnagar (TG), crop: Turmeric, is_merged = True
#       Processing crop group: Urad with 8 records
#     Created merged record: Karimnagar (TG), crop: Urad, is_merged = True
#       Processing crop group: Wheat with 3 records
#     Created merged record: Karimnagar (TG), crop: Wheat, is_merged = True
#   Hybrid Adilabad (TG): 4 of 4 constituents present
#     Present: ['Adilabad (TG)', 'Kumuram Bheem Asifabad (TG)', 'Mancherial (TG)', 'Nirmal (TG)']
#     -> MERGING 4 districts
#       Processing crop group: Arhar/Tur with 8 records
#     Created merged record: Adilabad (TG), crop: Arhar/Tur, is_merged = True
#       Processing crop group: Bajra with 2 records
#     Created merged record: Adilabad (TG), crop: Bajra, is_merged = True
#       Processing crop group: Banana with 3 records
#     Created merged record: Adilabad (TG), crop: Banana, is_merged = True
#       Processing crop group: Cashewnut with 2 records
#     Created merged record: Adilabad (TG), crop: Cashewnut, is_merged = True
#       Processing crop group: Castor seed with 3 records
#     Created merged record: Adilabad (TG), crop: Castor seed, is_merged = True
#       Processing crop group: Coriander with 4 records
#     Created merged record: Adilabad (TG), crop: Coriander, is_merged = True
#       Processing crop group: Cotton(lint) with 8 records
#     Created merged record: Adilabad (TG), crop: Cotton(lint), is_merged = True
#       Processing crop group: Cowpea(Lobia) with 8 records
#     Created merged record: Adilabad (TG), crop: Cowpea(Lobia), is_merged = True
#       Processing crop group: Dry chillies with 8 records
#     Created merged record: Adilabad (TG), crop: Dry chillies, is_merged = True
#       Processing crop group: Ginger with 2 records
#     Created merged record: Adilabad (TG), crop: Ginger, is_merged = True
#       Processing crop group: Groundnut with 7 records
#     Created merged record: Adilabad (TG), crop: Groundnut, is_merged = True
#       Processing crop group: Horse-gram with 4 records
#     Created merged record: Adilabad (TG), crop: Horse-gram, is_merged = True
#       Processing crop group: Jowar with 8 records
#     Created merged record: Adilabad (TG), crop: Jowar, is_merged = True
#       Processing crop group: Maize with 8 records
#     Created merged record: Adilabad (TG), crop: Maize, is_merged = True
#       Processing crop group: Moong(Green Gram) with 8 records
#     Created merged record: Adilabad (TG), crop: Moong(Green Gram), is_merged = True
#       Processing crop group: Onion with 4 records
#     Created merged record: Adilabad (TG), crop: Onion, is_merged = True
#       Processing crop group: Potato with 1 records
#     Created merged record: Adilabad (TG), crop: Potato, is_merged = True
#       Processing crop group: Ragi with 1 records
#     Created merged record: Adilabad (TG), crop: Ragi, is_merged = True
#       Processing crop group: Rice with 8 records
#     Created merged record: Adilabad (TG), crop: Rice, is_merged = True
#       Processing crop group: Safflower with 4 records
#     Created merged record: Adilabad (TG), crop: Safflower, is_merged = True
#       Processing crop group: Sesamum with 6 records
#     Created merged record: Adilabad (TG), crop: Sesamum, is_merged = True
#       Processing crop group: Small millets with 2 records
#     Created merged record: Adilabad (TG), crop: Small millets, is_merged = True
#       Processing crop group: Soyabean with 7 records
#     Created merged record: Adilabad (TG), crop: Soyabean, is_merged = True
#       Processing crop group: Sugarcane with 2 records
#     Created merged record: Adilabad (TG), crop: Sugarcane, is_merged = True
#       Processing crop group: Sweet potato with 2 records
#     Created merged record: Adilabad (TG), crop: Sweet potato, is_merged = True
#       Processing crop group: Tobacco with 1 records
#     Created merged record: Adilabad (TG), crop: Tobacco, is_merged = True
#       Processing crop group: Turmeric with 6 records
#     Created merged record: Adilabad (TG), crop: Turmeric, is_merged = True
#       Processing crop group: Urad with 8 records
#     Created merged record: Adilabad (TG), crop: Urad, is_merged = True
#       Processing crop group: Wheat with 5 records
#     Created merged record: Adilabad (TG), crop: Wheat, is_merged = True
#   Hybrid Senapati (MN): 1 of 2 constituents present
#     Present: ['Senapati (MN)']
#   Hybrid Ukhrul (MN): 1 of 2 constituents present
#     Present: ['Ukhrul (MN)']
#   Hybrid Thoubal (MN): 1 of 2 constituents present
#     Present: ['Thoubal (MN)']
#   Hybrid Imphal East (MN): 1 of 2 constituents present
#     Present: ['Imphal East (MN)']
#   Hybrid Tamenglong (MN): 1 of 2 constituents present
#     Present: ['Tamenglong (MN)']
#   Hybrid Churachandpur (MN): 1 of 2 constituents present
#     Present: ['Churachandpur (MN)']
#   Hybrid Chandel (MN): 1 of 2 constituents present
#     Present: ['Chandel (MN)']
#   Hybrid Bhiwani (HR): 2 of 2 constituents present
#     Present: ['Bhiwani (HR)', 'Charkhi Dadri (HR)']
#     -> MERGING 2 districts
#       Processing crop group: Bajra with 2 records
#     Created merged record: Bhiwani (HR), crop: Bajra, is_merged = True
#       Processing crop group: Barley with 2 records
#     Created merged record: Bhiwani (HR), crop: Barley, is_merged = True
#       Processing crop group: Cotton(lint) with 2 records
#     Created merged record: Bhiwani (HR), crop: Cotton(lint), is_merged = True
#       Processing crop group: Jowar with 2 records
#     Created merged record: Bhiwani (HR), crop: Jowar, is_merged = True
#       Processing crop group: Moong(Green Gram) with 2 records
#     Created merged record: Bhiwani (HR), crop: Moong(Green Gram), is_merged = True
#       Processing crop group: Rapeseed &Mustard with 2 records
#     Created merged record: Bhiwani (HR), crop: Rapeseed &Mustard, is_merged = True
#       Processing crop group: Rice with 2 records
#     Created merged record: Bhiwani (HR), crop: Rice, is_merged = True
#       Processing crop group: Wheat with 2 records
#     Created merged record: Bhiwani (HR), crop: Wheat, is_merged = True
#   Processing NAME CHANGE: Mangan (SK) -> North Sikkim (SK)
#     Found 7 records for name change
#     Created NAME_CHANGE record: North Sikkim (SK), crop: nan, is_merged = True
#     Created NAME_CHANGE record: North Sikkim (SK), crop: nan, is_merged = True
#     Created NAME_CHANGE record: North Sikkim (SK), crop: nan, is_merged = True
#     Created NAME_CHANGE record: North Sikkim (SK), crop: nan, is_merged = True
#     Created NAME_CHANGE record: North Sikkim (SK), crop: nan, is_merged = True
#     Created NAME_CHANGE record: North Sikkim (SK), crop: nan, is_merged = True
#     Created NAME_CHANGE record: North Sikkim (SK), crop: nan, is_merged = True
#   Processing NAME CHANGE: Namchi (SK) -> South Sikkhim (SK)
#     Found 8 records for name change
#     Created NAME_CHANGE record: South Sikkhim (SK), crop: nan, is_merged = True
#     Created NAME_CHANGE record: South Sikkhim (SK), crop: nan, is_merged = True
#     Created NAME_CHANGE record: South Sikkhim (SK), crop: nan, is_merged = True
#     Created NAME_CHANGE record: South Sikkhim (SK), crop: nan, is_merged = True
#     Created NAME_CHANGE record: South Sikkhim (SK), crop: nan, is_merged = True
#     Created NAME_CHANGE record: South Sikkhim (SK), crop: nan, is_merged = True
#     Created NAME_CHANGE record: South Sikkhim (SK), crop: nan, is_merged = True
#     Created NAME_CHANGE record: South Sikkhim (SK), crop: nan, is_merged = True
#   Processing NAME CHANGE: Ayodhya (UP) -> Faizabad (UP)
#     Found 29 records for name change
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Faizabad (UP), crop: nan, is_merged = True
#   Processing NAME CHANGE: Nuh (HR) -> Mewat (HR)
#     Found 8 records for name change
#     Created NAME_CHANGE record: Mewat (HR), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Mewat (HR), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Mewat (HR), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Mewat (HR), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Mewat (HR), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Mewat (HR), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Mewat (HR), crop: nan, is_merged = True
#     Created NAME_CHANGE record: Mewat (HR), crop: nan, is_merged = True
#   Merging happened this year: True
#   Unprocessed districts: 588
# Converting 106982 records to DataFrame...
# Before processing: 5629 merged records
# is_merged value counts: is_merged
# False    101353
# True       5629
# Name: count, dtype: int64
#
# Final result: 5629 merged records out of 106982 total
#
# === Validating results ===
#
# === Validation Results ===
# Year 2022: 16993 -> 14578 records, totals match: True, merged records: 900
# Year 2016: 15986 -> 14902 records, totals match: True, merged records: 435
# Year 2017: 16488 -> 15429 records, totals match: True, merged records: 438
# Year 2018: 16817 -> 15669 records, totals match: True, merged records: 465
# Year 2019: 17601 -> 16196 records, totals match: True, merged records: 534
# Year 2020: 17039 -> 15340 records, totals match: True, merged records: 641
# Year 2021: 16701 -> 14868 records, totals match: True, merged records: 664
#
# Merging summary: 5629 merged records, 101353 unmerged records out of 106982 total
#
# Saved harmonized data to: ../../data/temporally_harmonized_crop_data_072425.csv
#
# === Additional outputs ===
# Saved merging rules to: merging_rules.csv
# Saved validation results to: validation_results.csv
#
# === Sample of harmonized data ===
# Shape: (106982, 24)
# Columns: ['Data Source Organization', 'Data Source Document', 'Publication Name', 'Survey Type', 'Country', 'Zone', 'FNID', 'Admin 1', 'Admin 2', 'Admin 3', 'Year', 'Start Period', 'Season', 'End Period', 'Crop', 'Dominant Production System', 'Area Planted: ha', 'Area Harvested: ha', 'Yield: MT/ha', 'Quantity Produced: MT', 'Contributions by', 'Source crop', 'DNL_Source_year', 'is_merged']
#
# First few rows:
#   Data Source Organization                           Data Source Document  \
# 0          MoA & FW, India  Official agricultural statistics, India, crop
# 1          MoA & FW, India  Official agricultural statistics, India, crop
# 2          MoA & FW, India  Official agricultural statistics, India, crop
# 3          MoA & FW, India  Official agricultural statistics, India, crop
# 4          MoA & FW, India  Official agricultural statistics, India, crop
#
#                                     Publication Name Survey Type Country  \
# 0  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 1  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 2  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 3  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
# 4  https://data.desagri.gov.in/website/crops-apy-...  crop_final      IN
#
#    Zone  FNID         Admin 1          Admin 2  Admin 3  ...  Crop  \
# 0   NaN   NaN  Madhya Pradesh  Chhindwara (MP)      NaN  ...   NaN
# 1   NaN   NaN  Madhya Pradesh  Chhindwara (MP)      NaN  ...   NaN
# 2   NaN   NaN  Madhya Pradesh  Chhindwara (MP)      NaN  ...   NaN
# 3   NaN   NaN  Madhya Pradesh  Chhindwara (MP)      NaN  ...   NaN
# 4   NaN   NaN  Madhya Pradesh  Chhindwara (MP)      NaN  ...   NaN
#
#   Dominant Production System Area Planted: ha Area Harvested: ha  \
# 0                   All (PS)              NaN            18000.0
# 1                   All (PS)              NaN           179000.0
# 2                   All (PS)              NaN              260.0
# 3                   All (PS)              NaN             3010.0
# 4                   All (PS)              NaN            16000.0
#
#    Yield: MT/ha Quantity Produced: MT  Contributions by    Source crop  \
# 0          1.11               20000.0           Harvard  Small millets
# 1          3.23              578000.0           Harvard          Wheat
# 2         10.00                2600.0           Harvard   Dry chillies
# 3         20.00               60200.0           Harvard         Ginger
# 4          2.00               32000.0           Harvard          Jowar
#
#    DNL_Source_year  is_merged
# 0          2016-17      False
# 1          2016-17      False
# 2          2016-17      False
# 3          2016-17      False
# 4          2016-17      False
#
# [5 rows x 24 columns]
#
# Process complete!

# %% [markdown]
# # Let's see how the plot looks

# %%
test_path = "../../data/temporally_harmonized_crop_data_072425.csv"
ag_stats = pd.read_csv(test_path)

# %%
from matplotlib.colors import LinearSegmentedColormap
ag = ag_stats[['Admin 2', 'Year', 'Area Harvested: ha', 'Yield: MT/ha', 'Quantity Produced: MT', 'Source crop']]
ag.columns = ["name_state", "year", "area_harvested", "yield", "production", "ag_hy_crop"]

merged_hybrid = ag.merge(hybrid, how='left')
merged_hybrid = gpd.GeoDataFrame(merged_hybrid, geometry='geometry')

test = merged_hybrid[(merged_hybrid['ag_hy_crop']=="Rice") & (merged_hybrid['year']==2016)]
fig, ax = plt.subplots(figsize=(30, 20))
hybrid.boundary.plot(ax=ax, linewidth=1, color='black')
test.plot(ax=ax, column="yield", cmap='viridis', legend=True,)

plt.savefig('../plots/india_rice_yield_2016_071925.png')
