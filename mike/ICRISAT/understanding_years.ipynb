# %%
import pandas as pd
import numpy as np
import rasterio
import geopandas as gpd
import matplotlib.pyplot as plt
# from matplotlib import rc

# rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
# rc('text', usetex=True)

# %%
icrisat_path = '../shapefiles/icrisat_apportioned/'
shape_path = icrisat_path + 'icrisat_boundary_match.shp'
data_path = icrisat_path + 'ICRISAT-District Level Data_Apportioned.csv'

# %%
# Read the shapefile of district boundaries
districts = gpd.read_file(shape_path)

# Read the CSV containing crop data (which includes columns like 'district_name', 'year', 'crop', 'area', 'production', 'yield')
crop_data = pd.read_csv(data_path)

# Then merge
merged = districts.merge(crop_data, left_on="Dist_Name", right_on="Dist Name", how="left", indicator=True)

# %%
merged
# Out:
#       NAME_0  ID_0  ISO  ID_1          NAME_1  ID_2     NAME_2    TYPE_2  \
# 0      India   105  IND     2  Andhra Pradesh     3  Anantapur  District
# 1      India   105  IND     2  Andhra Pradesh     3  Anantapur  District
# 2      India   105  IND     2  Andhra Pradesh     3  Anantapur  District
# 3      India   105  IND     2  Andhra Pradesh     3  Anantapur  District
# 4      India   105  IND     2  Andhra Pradesh     3  Anantapur  District
# ...      ...   ...  ...   ...             ...   ...        ...       ...
# 16093  India   105  IND    36     West Bengal   594  Midnapore  District
# 16094  India   105  IND    36     West Bengal   594  Midnapore  District
# 16095  India   105  IND    36     West Bengal   594  Midnapore  District
# 16096  India   105  IND    36     West Bengal   594  Midnapore  District
# 16097  India   105  IND    36     West Bengal   594  Midnapore  District
#
#       ENGTYPE_2 NL_NAME_2  ... COTTON AREA (1000 ha)  \
# 0      District      None  ...                  42.0
# 1      District      None  ...                  35.0
# 2      District      None  ...                  31.5
# 3      District      None  ...                  33.6
# 4      District      None  ...                  31.0
# ...         ...       ...  ...                   ...
# 16093  District      None  ...                   0.0
# 16094  District      None  ...                   0.0
# 16095  District      None  ...                   0.0
# 16096  District      None  ...                   0.0
# 16097  District      None  ...                   0.0
#
#       COTTON PRODUCTION (1000 tons)  COTTON YIELD (Kg per ha)  \
# 0                               2.0                     47.62
# 1                               1.0                     28.57
# 2                               1.0                     31.75
# 3                               1.6                     47.62
# 4                               1.3                     41.94
# ...                             ...                       ...
# 16093                           0.0                      0.00
# 16094                           0.0                      0.00
# 16095                           0.0                      0.00
# 16096                           0.0                      0.00
# 16097                           0.0                      0.00
#
#        FRUITS AREA (1000 ha)  VEGETABLES AREA (1000 ha)  \
# 0                       9.41                       2.25
# 1                       9.18                       2.22
# 2                       9.69                       2.46
# 3                      10.15                       2.78
# 4                       9.59                       2.72
# ...                      ...                        ...
# 16093                  21.65                     166.88
# 16094                  21.75                     169.21
# 16095                  21.86                     191.83
# 16096                  21.97                     170.76
# 16097                  18.31                     160.14
#
#        FRUITS AND VEGETABLES AREA (1000 ha) POTATOES AREA (1000 ha)  \
# 0                                     11.66                    0.00
# 1                                     11.40                    0.00
# 2                                     12.15                    0.00
# 3                                     12.92                    0.00
# 4                                     12.31                    0.00
# ...                                     ...                     ...
# 16093                                188.52                   65.05
# 16094                                190.97                   66.36
# 16095                                213.69                   88.96
# 16096                                192.73                   66.12
# 16097                                178.45                   73.21
#
#       ONION AREA (1000 ha) FODDER AREA (1000 ha) _merge
# 0                     1.24                  1.15   both
# 1                     1.15                  0.58   both
# 2                     1.59                  0.80   both
# 3                     1.85                  0.97   both
# 4                     1.79                  1.35   both
# ...                    ...                   ...    ...
# 16093                 0.00                  0.00   both
# 16094                 0.00                  0.00   both
# 16095                 0.00                  0.00   both
# 16096                 0.00                  0.00   both
# 16097                 0.00                  0.00   both
#
# [16098 rows x 109 columns]
